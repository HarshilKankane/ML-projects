# %%
import pandas as pd
data=pd.read_csv("/content/winequality-red.csv")
data
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# ...

# %%
x=data.iloc[:,0:11].values
y=data.iloc[:,11:12].values
y.shape
# Out:
# (1599, 1)

# %%
import seaborn as sns
corr1=data.corr()
corr1
# Out:
#                       fixed acidity  volatile acidity  ...   alcohol   quality
# fixed acidity              1.000000         -0.256131  ... -0.061668  0.124052
# volatile acidity          -0.256131          1.000000  ... -0.202288 -0.390558
# citric acid                0.671703         -0.552496  ...  0.109903  0.226373
# residual sugar             0.114777          0.001918  ...  0.042075  0.013732
# chlorides                  0.093705          0.061298  ... -0.221141 -0.128907
# free sulfur dioxide       -0.153794         -0.010504  ... -0.069408 -0.050656
# total sulfur dioxide      -0.113181          0.076470  ... -0.205654 -0.185100
# density                    0.668047          0.022026  ... -0.496180 -0.174919
# pH                        -0.682978          0.234937  ...  0.205633 -0.057731
# sulphates                  0.183006         -0.260987  ...  0.093595  0.251397
# alcohol                   -0.061668         -0.202288  ...  1.000000  0.476166
# ...

# %%
sns.heatmap(corr1)

# %%
x=data.iloc[:,0:11].values
y=data.iloc[:,11:12].values #to be noted size defined point
y
# Out:
# array([[5],
#        [5],
#        [5],
#        ...,
#        [6],
#        [5],
#        [6]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
Lin=LinearRegression()
Lin.fit(x_train,y_train)
Lin1=LinearRegression()
Lin2=LinearRegression()
Lin3=LinearRegression()

# %%
y_pred = Lin.predict(x_test)
y_pred
# Out:
# array([[5.7829301 ],
#        [5.03619267],
#        [6.59698929],
#        [5.33912637],
#        [5.93952898],
#        [5.0072068 ],
#        [5.39616171],
#        [6.05211188],
#        [4.86760343],
#        [4.95067572],
#        [5.28580441],
#        [5.41265269],
#        [5.7057424 ],
#        [5.12921737],
#        [5.52885206],
#        [6.38052412],
#        [6.81012527],
#        [5.73803346],
#        [5.97618825],
#        [5.08613415],
#        [6.34479863],
#        [5.16400983],
#        [5.64203971],
#        [6.1462903 ],
#        [5.4817802 ],
#        [5.03391406],
#        [5.18721293],
#        [6.48783659],
#        [5.33301372],
#        [6.30458308],
#        [6.03452293],
#        [5.82849303],
#        [5.58503524],
#        [5.28512701],
#        [5.75656128],
#        [6.15273792],
#        [5.14134479],
#        [5.48228021],
#        [6.38983359],
#        [5.7901819 ],
#        [5.42936928],
#        [6.04810414],
#        [6.70159678],
# ...

# %%
data_new=data.drop(['fixed acidity','residual sugar','chlorides','free sulfur dioxide','density','total sulfur dioxide','citric acid','pH'],axis=1)
data_new
# Out:
#       volatile acidity  sulphates  alcohol  quality
# 0                0.700       0.56      9.4        5
# 1                0.880       0.68      9.8        5
# 2                0.760       0.65      9.8        5
# 3                0.280       0.58      9.8        6
# 4                0.700       0.56      9.4        5
# ...                ...        ...      ...      ...
# 1594             0.600       0.58     10.5        5
# 1595             0.550       0.76     11.2        6
# 1596             0.510       0.75     11.0        6
# 1597             0.645       0.71     10.2        5
# 1598             0.310       0.66     11.0        6
#
# [1599 rows x 4 columns]

# %%
x1=data_new['volatile acidity'].values
x2=data_new['sulphates']
x3=data_new['alcohol']
x1=x1.reshape(1599,1)
x2=x2.values.reshape(1599,1)
x3=x3.values.reshape(1599,1)

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y,test_size=0.2,random_state=0)
x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y,test_size=0.2,random_state=0)
x3_train,x3_test,y3_train,y3_test = train_test_split(x3,y,test_size=0.2,random_state=0)

# %%
Lin1.fit(x1_train,y1_train)
Lin2.fit(x2_train,y2_train)
Lin3.fit(x3_train,y3_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y1_pred=Lin1.predict(x1_test)
y2_pred=Lin2.predict(x2_test)
y3_pred=Lin3.predict(x3_test)

# %%
import matplotlib.pyplot as plt
plt.style.use('default')
plt.style.use('ggplot')
plt.plot(x1_test,y1_pred)
plt.plot(x2_test,y2_pred)
plt.plot(x3_test,y3_pred)
plt.scatter(x1_test,y1_pred)
plt.scatter(x2_test,y2_pred)
plt.scatter(x3_test,y3_pred)
plt.xlabel('Wine features')
plt.ylabel('Quality')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#MEAN ABSOLUTE ERROR
from sklearn.metrics import mean_absolute_error as mae
mae(y1_test,y1_pred)
# Out:
# 0.5491321250010273

# %%
mae(y2_test,y2_pred)

# %%
mae(y3_test,y3_pred)
# Out:
# 0.5179523528048385

# %%
#mean y
#predicted Quality
y_final=(y1_pred+y2_pred+y3_pred)/3
y_final
# Out:
# array([[5.76906674],
#        [5.32456212],
#        [6.0169276 ],
#        [5.43344578],
#        [5.68082016],
#        [5.40607196],
#        [5.44705303],
#        [5.83457673],
#        [5.20890756],
#        [5.38199254],
#        [5.47413953],
#        [5.5082558 ],
#        [5.64414059],
#        [5.46087645],
#        [5.58337309],
#        [5.97253261],
#        [6.1012681 ],
#        [5.67118442],
#        [5.75120346],
#        [5.37606374],
#        [5.84797911],
#        [5.50382628],
#        [5.62179659],
#        [5.85807862],
#        [5.65130412],
#        [5.43611716],
#        [5.4948477 ],
#        [6.00824205],
#        [5.57297208],
#        [5.95696234],
#        [5.79741071],
#        [5.77496711],
#        [5.61618924],
#        [5.51133401],
#        [5.65302808],
#        [5.8928151 ],
#        [5.50360437],
#        [5.61661599],
#        [5.97255536],
#        [5.67473486],
#        [5.56628651],
#        [5.78013917],
#        [6.11161222],
# ...

# %%
mae(y_test,y_final)
# Out:
# 0.5332214425270824

# %%
mae(y_final,y_pred)
# Out:
# 0.2494394455898568
